# %%
import os
import time
import urllib
import bs4
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import math

data = pd.read_excel('HBP.xlsx')

def get_email(website):
    try:
        with requests.Session() as s:
            base_page = s.get(website)
            soup = BeautifulSoup(base_page.content, 'html.parser')
            email = re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+",soup.text, re.I)
                
    except Exception:
        email = 'N/A'
    time.sleep(2)
    return email

for i in range(data.shape[0]):
    c = data['subcat description'][i]
    n = math.ceil(data['Taiwan Trade Supplier #'][i]/20)
    url = data['TW Trade URL'][i]
    links_with_text = []
    vendor_name=[]
    vendor_url=[]
    vendor_phone=[]

    for i in range(n):
        link = str(url+'&page='+str(i+1))
        with requests.Session() as s:
    
                base_page = s.get(link)
                soup = BeautifulSoup(base_page.content, 'html.parser')
                title = soup.find_all("h3")
    
                for h3 in title:
                    for link in h3.find_all('a'):
                        links_with_text.append(link.get('href'))
                        
                        time.sleep(2)
    if len(links_with_text)==0:
        for i in range(n):
            link = str(url.replace('search/','search?word=').replace('%20','+').replace('-',str('&type=product&page='+str(i+1)+'&style=')).replace('.html',''))
            with requests.Session() as s:
    
                base_page = s.get(link)
                soup = BeautifulSoup(base_page.content, 'html.parser')
                title = soup.find_all("h3")
    
                for h3 in title:
                    for link in h3.find_all('a'):
                        links_with_text.append(link.get('href'))
                        
                        time.sleep(2)
    new_links_with_text = []
    for i in links_with_text:
        if i.startswith('https:'):
            new_links_with_text.append(i)
        else:
            new_links_with_text.append(str('https://www.taiwantrade.com/'+i))
    
    for i in new_links_with_text:
        with requests.Session() as s:

            url_new=str(i+'/about-us')
            
            base_page = s.get(url_new)
            soup = BeautifulSoup(base_page.content, 'html.parser')
            txt = soup.find_all("span")
            text = soup.find_all("dd")
            header = soup.find('h3')
            try:
                vendor_url.append((str(txt).split(' <span itemprop="url">')[1]).split('</span')[0])
            except Exception:
                try:
                    base_page = s.get(i)
                    soup = BeautifulSoup(base_page.content, 'html.parser')
                    txt = soup.find_all("span")
                    text = soup.find_all("a", attrs={'class':'link'})
                    vendor_url.append(str(text).split('>')[1].split('<')[0])
                except Exception:
                    vendor_url.append('N/A')

            try:
                base_page = s.get(url_new)
                soup = BeautifulSoup(base_page.content, 'html.parser')
                txt = soup.find_all("span")
                text = soup.find_all("dd")
                header = soup.find('h3')
                vendor_phone.append((str(text).split('"telephone">')[1]).split('<')[0])
            except Exception:
                try:
                    txt = soup.find_all("span")
                    text = soup.find_all("dd")
                    header = soup.find('h3')
                    vendor_phone.append((str(text).split('"telephone">')[1]).split('<')[0])
                except Exception:
                    vendor_phone.append('N/A')

            try:
                base_page = s.get(url_new)
                soup = BeautifulSoup(base_page.content, 'html.parser')
                txt = soup.find_all("span")
                text = soup.find_all("dd")
                header = soup.find('h3')
                vendor_name.append(str(header).split('>')[1].split('<')[0])
            except Exception:
                try:
                    base_page = s.get(i)
                    soup = BeautifulSoup(base_page.content, 'html.parser')
                    txt = soup.find_all("span")
                    text = soup.find_all("a", attrs={'class':'link'})
                    vendor_name.append(str(txt).split(' <span itemprop="name">')[2].split('</span')[0])

                except Exception:
                    try:
                        base_page = s.get(url_new)
                        soup = BeautifulSoup(base_page.content, 'html.parser')
                        txt = soup.find_all("span")
                        text = soup.find_all("dd")
                        header = soup.find('h3')
                        vendor_name.append(str(header).split('>')[1].split('<')[0])
                    except Exception:
                        vendor_name.append('N/A')                        


    time.sleep(2)
    try:
        new_data = pd.DataFrame(
            {'Company_name': vendor_name,
             'Website': vendor_url,
             'Phone':vendor_phone
            })
        new_data['subcat description'] = c
        new_data['email'] = new_data['Website'].apply(lambda x: get_email(x))
        new_data.to_excel(str('Taitra_'+c.replace('/','-')+'.xlsx'),index=False)
    except Exception  as e: 
        print(e)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
len(new_links_with_text)
# Out:
# 40

# %%
new_links_with_text
# Out:
# ['https://dndbuildershardware.en.taiwantrade.com',
#  'https://howtool.en.taiwantrade.com',
#  'https://trehan.en.taiwantrade.com',
#  'https://fuin.en.taiwantrade.com',
#  'https://etai1977.en.taiwantrade.com',
#  'https://ppm.en.taiwantrade.com',
#  'https://secutor.en.taiwantrade.com',
#  'https://sunyuta.en.taiwantrade.com',
#  'https://zuda.en.taiwantrade.com',
#  'https://orgalin.en.taiwantrade.com',
#  'https://allwin.en.taiwantrade.com',
#  'https://saracheninternational.en.taiwantrade.com',
#  'https://decatur.en.taiwantrade.com',
#  'https://solidgold.en.taiwantrade.com',
#  'https://armstrong.en.taiwantrade.com',
#  'https://www.taiwantrade.com//company/el-sunchief-international-co-ltd-148787.html',
#  'https://www.taiwantrade.com//company/jane-mark-enterprise-co-ltd-4614.html',
#  'https://sltech-auto.en.taiwantrade.com',
#  'https://amexhardware.en.taiwantrade.com',
#  'https://isdhardware.en.taiwantrade.com',
#  'https://sunsing.en.taiwantrade.com',
#  'https://www.taiwantrade.com//company/long-may-industrial-co-ltd-153672.html',
#  'https://www.taiwantrade.com//company/mayfair-hardware-corporation-2928.html',
#  'https://topjingle.en.taiwantrade.com',
#  'https://puffdino.en.taiwantrade.com',
#  'https://www.taiwantrade.com//company/goal-den-international-co-ltd-359587.html',
#  'https://onsun98.en.taiwantrade.com',
#  'https://slamdunk.en.taiwantrade.com',
#  'https://buildray.en.taiwantrade.com',
#  'https://hermesclues.en.taiwantrade.com',
#  'https://lipson.en.taiwantrade.com',
#  'https://ezset.en.taiwantrade.com',
#  'https://changyue.en.taiwantrade.com',
#  'https://reallock.en.taiwantrade.com',
#  'https://houlih.en.taiwantrade.com',
#  'https://sunsight.en.taiwantrade.com',
#  'https://asmith.en.taiwantrade.com',
#  'https://twoc.en.taiwantrade.com',
#  'https://keyman.en.taiwantrade.com',
#  'https://globelock.en.taiwantrade.com']

# %%
vendor_url
# Out:
# ['http://www.dnd.com.tw',
#  'https://www.howtool.com.tw/',
#  'N/A',
#  'N/A',
#  'http://www.fuin.tw',
#  'http://export.itai.com.tw',
#  'http://www.ppm.com.tw',
#  'http://www.secutor.com.tw/',
#  'http://www.sunyuta.com.tw/',
#  'http://www.zuda.com.tw',
#  'http://orgalin.taiwantrade.com.tw',
#  'https://www.allwinhardware.com',
#  'http://www.taiwantrade.com.tw/saracheninternational',
#  'http://www.decaturhardware.com',
#  'http://solidgold.taiwantrade.com.tw/',
#  'http://www.armstronglocks.com',
#  'http://www.taiwantrade.com.tw/sunchief',
#  'N/A',
#  'http://sltech-auto.com',
#  'http://www.amexlock.com',
#  'http://www.isd-hardware.com/',
#  'N/A',
#  'N/A',
#  'http://www.longmay.com.tw',
#  'http://www.mayfair.com.tw',
#  'http://www.topjle.com.tw',
#  'http://www.puffdino.com/',
#  'http://www.twgdi.com',
#  'http://www.onsun98.com.tw/',
#  'http://www.slamdunk.com.tw',
#  'http://www.buildray-sports.com',
#  'http://www.hermes-clues.com',
#  'http://www.lipson.com.tw',
#  'http://www.ezset.com.tw/en/',
#  'N/A',
#  'N/A',
#  'http://www.reallock.com',
#  'http://www.houlih.com.tw',
#  'http://www.taiwantrade.com.tw/sunsight',
#  'https://www.asmith.com.tw',
#  'http://www.twoc.com.tw',
#  'http://www.keyman-twn.com.tw',
#  'http://www.globelock.com.tw']

# %%
vendor_name
# Out:
# ['D&amp;D BUILDERS HARDWARE CO.',
#  'HSI YI ENTERPRISE CO., LTD.',
#  'TREHAN INDUSTRIAL CO., LTD.',
#  'FU IN C. M. ENTERPRISE CORPORATION',
#  'E TAI ENTERPRISE CO., LTD.',
#  'RAINBOW MING INDUSTRIAL CO., LTD.',
#  'SECUTOR CORPORATION',
#  'SUN YU TA CO., LTD.',
#  'ZUDA INDUSTRIAL CO., LTD.',
#  'ORGALIN HOUSEWARE CO., LTD.',
#  'ALLWIN ARCHITECTURAL HARDWARE INC.',
#  'SARA CHEN INTERNATIONAL CO., LTD.',
#  'DECATUR INDUSTRIES INC.',
#  'SOLID GOLD HARDWARE CORPORATION',
#  'BAI FU CO., LTD.',
#  'EL SUNCHIEF INTERNATIONAL CO., LTD.',
#  'JANE MARK ENTERPRISE CO.,  LTD.',
#  'SHINE LONG ELECTRONIC COMPANY',
#  'AMEX HARDWARE CO., LTD.',
#  'ISD HARDWARE CO., LTD.',
#  'SUN SING INDUSTRY CO.',
#  'LONG MAY INDUSTRIAL  CO., LTD.',
#  'MAYFAIR HARDWARE CORPORATION',
#  'TOP JINGLE DEVELOPMENT CO., LTD.',
#  'INTERTRUST CORPORATION',
#  'GOAL DEN INTERNATIONAL CO., LTD.',
#  'EVER DIGNITY INDUSTRY CO., LTD.',
#  'SLAM DUNK ENTERPRISE CO., LTD.',
#  'BUILD RAY ENTERPRISE CO., LTD.',
#  'HERMES CLUES INDUSTRIES CO., LTD.',
#  'LIPSON ENTERPRISE CO., LTD.',
#  'TONG LUNG METAL INDUSTRY CO., LTD.',
#  'CHANG YUE INDUSTRIAL CORPORATION',
#  'REAL LOCKS &amp; SECURITY CO., LTD.',
#  'HOU LIH CO., LTD.',
#  'SUNSIGHT LIMITED',
#  'ASMITH MANUFACTURING COMPANY',
#  '2C ENTERPRISE CO., LTD.',
#  'KEYMAN INTERNATIONAL CORPORATION',
#  'GLOBE LOCK AND HARDWARE INC.']
